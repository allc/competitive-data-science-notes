# %% [markdown]
# # Feature preprocessing and generation with respect to models
#
# > Guided by Coursera course "[How to Win a Data Science Competition: Learn from Top Kagglers](https://www.coursera.org/learn/competitive-data-science)".
#
# ## Overview
#
# Features:
#
# - Numeric
# - Categorical
# - Ordinal
# - Datetime
# - Coordinates
#
# Feature processing is often necessary
#
# Feature generation is powerful technique
#
# Preprocessing and generation pipelines depend on a model type
#
# Feature generation is powered by:
#
# - Prior knowledge
# - Exploratory data analysis
#
# ### Tricks
#
# Train model on concatenated data frames produced by different preprocessings or to mix models training differently-preprocessed data
#
# ## Numeric features
#
# ### Preprocessing
#
# - Scaling
#   - To [0,1]
#
#     `sklearn.preprocessing.MinMaxScaler`
#
#   - To mean=0, std=1
#
#     `sklearn.preprocessing.StandardScaler`
#
#   - Tree-based models doesn't depend on scaling
#
#   - Non-tree based models hugely depend on scaling
#
# - Outliers
#
# - Rank: Set spaces between sorted values to be equal
#
#   `scipy.stats.rankdata`
#
# - Drive too big values closer to the features' average value
#   - Log transform
#
#     `np.log(1+x)`
#
#   - Raising to the power < 1
#
#     `np.sqrt(x+2/3)`
#
# ## Categorical and ordinal features
#
# - Label encoding
#
#   - Alphabetical (sorted)
#
#     `sklearn.preprocessing.LabelEncoder`
#
#   - Order of appearance
#
#     `pandas.factorize`
#
# - Freuency encoding
#
# ## Datetime and coordinates
#
# ### Date and time
#
# - Periodicity
# - Time since
# - Difference between dates
#
# ### Coordinates
#
# - Interesting places from train/test data or additional data
# - Centers of clusters
# - Aggregated statistics
#
# ## Handling missing values
#
# ### Fillna approaches
#
# - -999, -1 etc.
# - mean, median
# - reconstruct value
#
# ### "Isnull" feature
